# %%
import matplotlib
import pandas as pd

# %%
df = pd.read_csv('flight.csv')

# %%
df
# Out:
#      flight_id departure_airport arrival_airport     rubles  minutes  \
# 0       136807               AAQ             EGO   531000.0     50.0
# 1       136642               AAQ             EGO   531000.0     49.0
# 2       136844               AAQ             EGO   575100.0     50.0
# 3       136887               AAQ             EGO   595200.0     49.0
# 4       136922               AAQ             EGO   607800.0     50.0
# ..         ...               ...             ...        ...      ...
# 113     136275               AAQ             SVO  1825000.0     98.0
# 114     136389               AAQ             SVO  1873800.0    100.0
# 115     136403               AAQ             SVO  1873800.0    100.0
# 116     136226               AAQ             SVO  1886000.0    100.0
# 117     136316               AAQ             SVO  1886000.0    100.0
#
#      rubles_per_min  seats_counter  saled_tickets
# 0      10620.000000             97             68
# ...

# %%
df.groupby('arrival_airport').median()
# Out:
#                  flight_id     rubles  minutes  rubles_per_min  seats_counter  \
# arrival_airport
# EGO                 136769   746400.0     50.0    14882.352941             97
# SVO                 136284  1628600.0    100.0    16366.336634            130
#
#                  saled_tickets
# arrival_airport
# EGO                         95
# SVO                        112
