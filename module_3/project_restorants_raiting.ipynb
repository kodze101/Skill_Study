# %%
import pandas as pd
df= pd.read_csv("Main_task.csv")

# %%
df.fillna(df.median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant_id            0
# City                     0
# Cuisine Style         9283
# Ranking                  0
# Rating                   0
# Price Range          13886
# Number of Reviews        0
# Reviews                  0
# URL_TA                   0
# ID_TA                    0
# dtype: int64

# %%
df[df['Price Range']=='$$ - $$$']
# Out:
#       Restaurant_id    City  \
# 0           id_5569   Paris
# 4            id_615  Munich
# 11          id_5312  London
# 12          id_4066  London
# 13          id_4637  Berlin
# ...             ...     ...
# 39994       id_7074   Paris
# 39995        id_499   Milan
# 39996       id_6340   Paris
# 39998        id_640  Warsaw
# 39999       id_4824   Milan
#
#                                            Cuisine Style  Ranking  Rating  \
# 0                ['European', 'French', 'International']   5570.0     3.5
# 4      ['German', 'Central European', 'Vegetarian Fri...    621.0     4.0
# 11           ['Italian', 'Pizza', 'Vegetarian Friendly']   5321.0     4.0
# 12     ['Italian', 'Pizza', 'Vegetarian Friendly', 'G...   4073.0     3.5
# 13        ['Vegetarian Friendly', 'Gluten Free Options']   4639.0     4.5
# ...                                                  ...      ...     ...
# 39994  ['French', 'Fast Food', 'Mediterranean', 'Heal...   7075.0     4.5
# 39995  ['Italian', 'Vegetarian Friendly', 'Vegan Opti...    500.0     4.5
# 39996  ['French', 'American', 'Bar', 'European', 'Veg...   6341.0     3.5
# 39998  ['Polish', 'European', 'Eastern European', 'Ce...    641.0     4.0
# 39999                                        ['Spanish']   4827.0     3.0
#
#       Price Range  Number of Reviews  \
# 0        $$ - $$$              194.0
# 4        $$ - $$$               84.0
# 11       $$ - $$$               42.0
# 12       $$ - $$$              286.0
# 13       $$ - $$$               10.0
# ...           ...                ...
# 39994    $$ - $$$                6.0
# 39995    $$ - $$$               79.0
# 39996    $$ - $$$              542.0
# 39998    $$ - $$$               70.0
# 39999    $$ - $$$              260.0
#
#                                                  Reviews  \
# 0      [['Good food at your doorstep', 'A good hotel ...
# 4      [['Best place to try a Bavarian food', 'Nice b...
# 11     [['Not bad for Canary Wharf', 'To be a pilgrim...
# 12     [['Great service, good za', 'Lovely, relaxed a...
# 13     [['What a great spot!', 'Healthy superfoods, v...
# ...                                                  ...
# 39994                                           [[], []]
# 39995  [['The real Italian experience!', 'Wonderful f...
# 39996  [['Parisian atmosphere', 'Bit pricey but inter...
# 39998  [['Underground restaurant', 'Oldest Restaurant...
# 39999  [['Average', 'Nice an informal'], ['01/31/2016...
#
#                                                   URL_TA      ID_TA
# 0      /Restaurant_Review-g187147-d1912643-Reviews-R_...   d1912643
# 4      /Restaurant_Review-g187309-d6864963-Reviews-Au...   d6864963
# 11     /Restaurant_Review-g186338-d12402429-Reviews-P...  d12402429
# 12     /Restaurant_Review-g186338-d2259559-Reviews-Ma...   d2259559
# 13     /Restaurant_Review-g187323-d12107166-Reviews-L...  d12107166
# ...                                                  ...        ...
# 39994  /Restaurant_Review-g187147-d12621988-Reviews-C...  d12621988
# 39995  /Restaurant_Review-g187849-d2104414-Reviews-Ro...   d2104414
# 39996  /Restaurant_Review-g187147-d1800036-Reviews-La...   d1800036
# 39998  /Restaurant_Review-g274856-d1100838-Reviews-Ho...   d1100838
# 39999  /Restaurant_Review-g187849-d1109020-Reviews-Ta...   d1109020
#
# [18412 rows x 10 columns]

# %%
def bzz(row):
    i= str(df['Reviews'].values)
    
    a=i.split('], ')[1].split(',')[0].replace('[','')
    if len(a)!=2:
        if a[-1]==']':
            a=a[:-2]
        a=a[1:-1]
        print(a)
        return a
    return '16/02/2021'

# %%
df['date']=df.apply(bzz)
# Out:
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017
# 12/31/2017

# %%
df
# Out:
#       Restaurant_id       City  \
# 0           id_5569      Paris
# 1           id_1535  Stockholm
# 2            id_352     London
# 3           id_3456     Berlin
# 4            id_615     Munich
# ...             ...        ...
# 39995        id_499      Milan
# 39996       id_6340      Paris
# 39997       id_1649  Stockholm
# 39998        id_640     Warsaw
# 39999       id_4824      Milan
#
#                                            Cuisine Style  Ranking  Rating  \
# 0                ['European', 'French', 'International']   5570.0     3.5
# 1                                                    NaN   1537.0     4.0
# 2      ['Japanese', 'Sushi', 'Asian', 'Grill', 'Veget...    353.0     4.5
# 3                                                    NaN   3458.0     5.0
# 4      ['German', 'Central European', 'Vegetarian Fri...    621.0     4.0
# ...                                                  ...      ...     ...
# 39995  ['Italian', 'Vegetarian Friendly', 'Vegan Opti...    500.0     4.5
# 39996  ['French', 'American', 'Bar', 'European', 'Veg...   6341.0     3.5
# 39997                              ['Japanese', 'Sushi']   1652.0     4.5
# 39998  ['Polish', 'European', 'Eastern European', 'Ce...    641.0     4.0
# 39999                                        ['Spanish']   4827.0     3.0
#
#       Price Range  Number of Reviews  \
# 0        $$ - $$$              194.0
# 1             NaN               10.0
# 2            $$$$              688.0
# 3             NaN                3.0
# 4        $$ - $$$               84.0
# ...           ...                ...
# 39995    $$ - $$$               79.0
# 39996    $$ - $$$              542.0
# 39997         NaN                4.0
# 39998    $$ - $$$               70.0
# 39999    $$ - $$$              260.0
#
#                                                  Reviews  \
# 0      [['Good food at your doorstep', 'A good hotel ...
# 1      [['Unique cuisine', 'Delicious Nepalese food']...
# 2      [['Catch up with friends', 'Not exceptional'],...
# 3                                               [[], []]
# 4      [['Best place to try a Bavarian food', 'Nice b...
# ...                                                  ...
# 39995  [['The real Italian experience!', 'Wonderful f...
# 39996  [['Parisian atmosphere', 'Bit pricey but inter...
# 39997  [['Good by swedish standards', 'A hidden jewel...
# 39998  [['Underground restaurant', 'Oldest Restaurant...
# 39999  [['Average', 'Nice an informal'], ['01/31/2016...
#
#                                                   URL_TA     ID_TA date
# 0      /Restaurant_Review-g187147-d1912643-Reviews-R_...  d1912643  NaN
# 1      /Restaurant_Review-g189852-d7992032-Reviews-Bu...  d7992032  NaN
# 2      /Restaurant_Review-g186338-d8632781-Reviews-RO...  d8632781  NaN
# 3      /Restaurant_Review-g187323-d1358776-Reviews-Es...  d1358776  NaN
# 4      /Restaurant_Review-g187309-d6864963-Reviews-Au...  d6864963  NaN
# ...                                                  ...       ...  ...
# 39995  /Restaurant_Review-g187849-d2104414-Reviews-Ro...  d2104414  NaN
# 39996  /Restaurant_Review-g187147-d1800036-Reviews-La...  d1800036  NaN
# 39997  /Restaurant_Review-g189852-d947615-Reviews-Sus...   d947615  NaN
# 39998  /Restaurant_Review-g274856-d1100838-Reviews-Ho...  d1100838  NaN
# 39999  /Restaurant_Review-g187849-d1109020-Reviews-Ta...  d1109020  NaN
#
# [40000 rows x 11 columns]

# %%
# Разбиваем датафрейм на части, необходимые для обучения и тестирования модели  
    # Х - данные с информацией о ресторанах, у - целевая переменная (рейтинги ресторанов)  
X = df.drop(['Restaurant_id', 'Rating','Cuisine Style','Price Range','ID_TA','URL_TA','Reviews','City'], axis = 1)  
y = df['Rating']  
      
# Загружаем специальный инструмент для разбивки:  
from sklearn.model_selection import train_test_split  
  
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.  
# Для тестирования мы будем использовать 25% от исходного датасета.  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
# Импортируем необходимые библиотеки:  
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели  
from sklearn import metrics # инструменты для оценки точности модели  
  
# Создаём модель  
regr = RandomForestRegressor(n_estimators=100)  
      
# Обучаем модель на тестовом наборе данных  
regr.fit(X_train, y_train)  
      
# Используем обученную модель для предсказания рейтинга ресторанов в тестовой выборке.  
# Предсказанные значения записываем в переменную y_pred  
y_pred = regr.predict(X_test)

# %%
  print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.435176640458153

# %%
import pandas as pd
df2= pd.read_csv('RR.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-104-f8a7bc7fd126> in <module>
#       1 import pandas as pd
# ----> 2 df2= pd.read_csv('RR.csv')
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File RR.csv does not exist: 'RR.csv'

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-2068723f1203> in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined
